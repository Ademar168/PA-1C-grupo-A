# %% [markdown]
# <a href="https://colab.research.google.com/github/Ademar168/PA-1C-grupo-A/blob/main/helloword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello word")
nome = ("ademar") # variável tipo str (string
idade = 15 # variavel número inteiro
altura = 1.7 # variável tipo float
# Out:
# hello word

# %% [markdown]
# #entrada
#
# lado-6
#
# #processamento
#
# quadrado = lado  * lado
#
# #saida
#
# print(f" total da área do quadrado)

# %%
#entrada

lado = -9

#processamento

quadrado = lado  * lado

#saida



print (f"total da área do quadrado é: {quadrado}")
# Out:
# total da área do quadrado é: 81

# %% [markdown]
# #entrada
#
# comprimento = 7
#
# altura = 3
#
# #processamento
#
# area=comprimento * altura
#
# #saida
#
#
# print(f"total da area:(area)")

# %%
#entrada

comprimento = 7

altura = 3

#processamento

area=comprimento * altura

#saida


print(f"total da area: {area}")
# Out:
# total da area: 21

# %% [markdown]
# faça um programa que recebe 04 notas do aluno e calcula a média depois mostrar a média
# #entrada
# nota1,nota2,nota3,nota4
#
# #processamento
#
# calcular media das notas
#
# #saida
#
# mostrar media

# %%
#entrada

nota1 = 7
nota2 = 8
nota3 = 10
nota4 = 10

media = (nota1 + nota2 + nota3 + nota4) / 4

#saida

print(media)
# Out:
# 8.75

# %% [markdown]
# #calcular a área do retangulo
#
#
# #entrada
#
# comprimento= float (imput("digite o comprimento))
# altura= float (imput(digite o valor da altura))
#
# #processamento
#
# área=comprimento * altura
#
# #saida
#
# print

# %%
#calcular a área do retangulo


#entrada

comprimento= float (imput("digite o comprimento))
altura= float (imput(digite o valor da altura))

#processamento

área=comprimento * altura

#saida

print ( "----------ÁREA DO RETANGULO ------------")
print ("")
print (f"A área total do retangulo é igual :{area}")
print ("")
print ("-------------------------------------------")
# Out:
#   File "/tmp/ipykernel_307/3683993814.py", line 6
#     comprimento= float (imput("digite o comprimento))
#                               ^
# SyntaxError: unterminated string literal (detected at line 6)

# %% [markdown]
# fazer um programa que converte a temperatura de celsius para fahrenheit.
#
# Entrada : graus celsius
#
# processamento:converte a temperatura para fahrenheit
#
# saida : mostrar a temperatura em fahrenheit
#
# F=(C x 9/5) +32

# %%
# Entrada

celsius = int (imput ("digite a temperatuta: ")

# processamento

fahrenheit = (celsius * 9/5 +32)

#saida

print("")
print("------------TEMPERATURA ----------")
print ("")

# %%
# operadores aritiméticos


# soma de dois números

# entrada

a = int (imput ("digite o primeiro número: "))
b = int (imput ("digite o segundo número:"))

# processamento

#soma de dois números

soma = a + b
subtração = a - b
multiplicação = a * b
divisao = a / b
div_int = a // b
resto = a %

#saida
print("")
print("--------------SOMA------------")
print("")
print(f"A soma de {a} mais {b}") é igual a: {soma}")
print("")
print("--------------SUBTRAÇÃO------------")
print("")
print(f"A subtração de {a} menos {b}" é igual a: {subtração}")
print("")
print(f"-------------MULTIPLICAÇÃO-------------")
print
