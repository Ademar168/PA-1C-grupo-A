# %% [markdown]
# <a href="https://colab.research.google.com/github/Ademar168/PA-1C-grupo-A/blob/main/helloword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello word")
nome = ("ademar") # variável tipo str (string
idade = 15 # variavel número inteiro
altura = 1.7 # variável tipo float
# Out:
# hello word

# %% [markdown]
# #entrada
#
# lado-6
#
# #processamento
#
# quadrado = lado  * lado
#
# #saida
#
# print(f" total da área do quadrado)

# %%
#entrada

lado = -9

#processamento

quadrado = lado  * lado

#saida



print (f"total da área do quadrado é: {quadrado}")
# Out:
# total da área do quadrado é: 81

# %% [markdown]
# #entrada
#
# comprimento = 7
#
# altura = 3
#
# #processamento
#
# area=comprimento * altura
#
# #saida
#
#
# print(f"total da area:(area)")

# %%
#entrada

comprimento = 7

altura = 3

#processamento

area=comprimento * altura

#saida


print(f"total da area: {area}")
# Out:
# total da area: 21

# %% [markdown]
# faça um programa que recebe 04 notas do aluno e calcula a média depois mostrar a média
# #entrada
# nota1,nota2,nota3,nota4
#
# #processamento
#
# calcular media das notas
#
# #saida
#
# mostrar media

# %%
#entrada

nota1 = 7
nota2 = 8
nota3 = 10
nota4 = 10

media = (nota1 + nota2 + nota3 + nota4) / 4

#saida

print(media)
# Out:
# 8.75

# %% [markdown]
# Escrever um algoritimo e o programa que calcula a área
